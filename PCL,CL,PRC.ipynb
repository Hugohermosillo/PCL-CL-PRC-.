# %% [markdown]
# <a href="https://colab.research.google.com/github/Hugohermosillo/PCL-CL-PRC-./blob/main/PCL%2CCL%2CPRC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Texto de título predeterminado
# Importar o instalar xlsxwriter si es necesario
try:
    import xlsxwriter
except ModuleNotFoundError:
    # !pip install xlsxwriter
    import xlsxwriter

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from ipywidgets import interactive, Dropdown, IntSlider
from IPython.display import display, clear_output

# Configuración de Seaborn para una gráfica estilizada
sns.set(style='whitegrid')

# Datos iniciales
data = {
     'Meses': ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio',
               'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre'],
    'PPC%': [100, 95, 90, 85, 80, 75, 70, 65, 60, 55, 50, 45],
    'CL%': [100, 98, 95, 93, 90, 88, 85, 83, 80, 78, 75, 73],
    'PRC%': [100, 97, 93, 90, 85, 82, 78, 75, 70, 67, 63, 60]
}
df = pd.DataFrame(data)

# Función para guardar la gráfica como imagen
def save_figure(df, filename='chart.png'):
    plt.figure(figsize=(10, 6))
    for column in df.columns[1:]:
        plt.plot(df['Meses'], df[column], marker='o', linewidth=2, label=f'{column}')
    plt.title('Evolución de PPC%, CL% y PRC%', fontsize=18, fontweight='bold')
    plt.xlabel('Meses', fontsize=14)
    plt.ylabel('Porcentaje (%)', fontsize=14)
    plt.xticks(rotation=45)  # Rotar las etiquetas del eje x para evitar la superposición
    plt.ylim(0, 110)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()  # Ajustar la disposición de la gráfica
    plt.savefig(filename, dpi=300)  # Guardar con alta resolución
    plt.close()

# Función para mostrar la gráfica en Python
def plot_data(df):
    plt.figure(figsize=(10, 6))
    for column in df.columns[1:]:
        plt.plot(df['Meses'], df[column], marker='o', linewidth=2, label=f'{column}')
    plt.title('Evolución de PPC%, CL% y PRC%', fontsize=18, fontweight='bold')
    plt.xlabel('Meses', fontsize=14)
    plt.ylabel('Porcentaje (%)', fontsize=14)
    plt.xticks(rotation=45)  # Rotar las etiquetas del eje x para evitar la superposición
    plt.ylim(0, 110)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()  # Ajustar la disposición de la gráfica
    plt.show()

# Los widgets y la función de interactividad permanecen igual

# Widgets para la interacción del usuario
month_selector = Dropdown(options=df['Meses'], value='Febrero', description='Mes:')
ppc_slider = IntSlider(min=0, max=100, value=100, description='PPC%', continuous_update=False)
cl_slider = IntSlider(min=0, max=100, value=100, description='CL%', continuous_update=False)
prc_slider = IntSlider(min=0, max=100, value=100, description='PRC%', continuous_update=False)
interactive_widgets = interactive(update_and_export, month=month_selector, ppc=ppc_slider, cl=cl_slider, prc=prc_slider)

# Mostrar los widgets y la gráfica inicial
display(interactive_widgets)
# Out:
# interactive(children=(Dropdown(description='Mes:', index=1, options=('Enero', 'Febrero', 'Marzo', 'Abril', 'Ma…
